# %%
import json

# %%
EPITOPE = 'SIINFEKL'

# %%
path_out = f'../results/active_learning/across/crossTCR_FULL_random_8_10.json'
with open(path_out) as f:
    results_exp = json.load(f)

# %%
results_exp
# Out:
# {'MAE': [['ED5', 0, 16.05810510487147],
#   ['ED5', 1, 16.066326601816577],
#   ['ED5', 2, 15.752163386379824],
#   ['ED5', 3, 15.477894031354099],
#   ['ED5', 4, 15.217296183600128],
#   ['ED5', 5, 15.382461715355138],
#   ['ED5', 6, 15.591369087513721],
#   ['ED5', 7, 15.15914564939332],
#   ['ED5', 8, 15.764213540206766],
#   ['ED5', 9, 15.746448758692539],
#   ['ED8', 0, 26.265419947899154],
#   ['ED8', 1, 26.1685998974109],
#   ['ED8', 2, 27.557790593999194],
#   ['ED8', 3, 27.239003787752015],
#   ['ED8', 4, 27.61117653082391],
#   ['ED8', 5, 27.271685103042742],
#   ['ED8', 6, 27.044895501201875],
#   ['ED8', 7, 26.545165952909425],
#   ['ED8', 8, 26.74942266268168],
#   ['ED8', 9, 27.28942089962224],
#   ['ED9', 0, 12.80892740481371],
#   ['ED9', 1, 13.050315663585414],
#   ['ED9', 2, 13.067683860614258],
#   ['ED9', 3, 13.127408581310114],
#   ['ED9', 4, 13.025305130755397],
#   ['ED9', 5, 13.136536899944113],
#   ['ED9', 6, 12.856959044528317],
# ...
